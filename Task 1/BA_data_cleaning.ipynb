# %% [markdown]
# # Importing and cleaning data

# %%
#imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

#regex
import re

#create a dataframe from csv file
cwd = os.getcwd()

df = pd.read_csv(cwd+"/BA.csv", index_col=0)
df.head()
# Out:
#                                              Reviews  Ratings  \
# 0  ✅ Trip Verified |  At 7.54 am on the day of tr...      2.0
# 1  ✅ Trip Verified |  Would happily fly them agai...     10.0
# 2  Not Verified |  Flew premium, only worth the e...      4.0
# 3  ✅ Trip Verified |  First our morning flight wa...      1.0
# 4  ✅ Trip Verified |  Although it was a bit uncom...      8.0
#
#        Aircraft Type       Traveller       Countries    Flight Ticket  \
# 0                NaN    Solo Leisure  United Kingdom    Economy Class
# 1  Boeing 777 / A320    Solo Leisure   United States    Economy Class
# 2                NaN  Couple Leisure  United Kingdom  Premium Economy
# 3            A321neo        Business          Canada   Business Class
# 4         Boeing 787    Solo Leisure  United Kingdom    Economy Class
#
#                              Route     Date Flown  Seat Comfort /5  \
# 0            London to Los Angeles     March 2023              1.0
# 1  New York to Istanbul via London     March 2023              5.0
# 2     London Heathrow to Las Vegas     March 2023              3.0
# 3                  London to Cairo   January 2023              1.0
# 4                London Singapore   February 2023              3.0
#
#    Cabin Staff Services /5  Food and beverages /5  Ground service /5  \
# 0                      2.0                    1.0                3.0
# 1                      5.0                    5.0                5.0
# 2                      2.0                    1.0                2.0
# 3                      2.0                    1.0                3.0
# 4                      5.0                    5.0                5.0
#
#    Value for money /5 Recommended
# 0                   1          no
# 1                   5         yes
# 2                   3          no
# 3                   1          no
# 4                   4         yes

# %%
# creating 'vertified' column from "reviews"
df['verified'] = df.Reviews.str.contains("Trip Verified")
df['verified']
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 3480    False
# 3481    False
# 3482    False
# 3483    False
# 3484    False
# Name: verified, Length: 3485, dtype: bool

# %% [markdown]
# REVIEW CLEANING

# %%
#for lemmatization of words we will use nltk library
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
lemma = WordNetLemmatizer()


reviews_data = df.Reviews.str.strip("✅ Trip Verified |")

#create an empty list to collect cleaned data corpus
corpus =[]

#loop through each review, remove punctuations, small case it, join it and add it to corpus
for rev in reviews_data:
    rev = re.sub('[^a-zA-Z]',' ', rev)
    rev = rev.lower()
    rev = rev.split()
    rev = [lemma.lemmatize(word) for word in rev if word not in set(stopwords.words("english"))]
    rev = " ".join(rev)
    corpus.append(rev)

# add the corpus to the original dataframe
df['corpus'] = corpus

# %%
# date format
df.dtypes
# convert the "Date Flown" column to datetime format
df['Date Flown'] = pd.to_datetime(df['Date Flown'])
df['Date Flown'].head()
# Out:
# 0   2023-03-01
# 1   2023-03-01
# 2   2023-03-01
# 3   2023-01-01
# 4   2023-02-01
# Name: Date Flown, dtype: datetime64[ns]

# %%
df['Date Flown']
# Out:
# 0      2023-03-01
# 1      2023-03-01
# 2      2023-03-01
# 3      2023-01-01
# 4      2023-02-01
#           ...
# 3480          NaT
# 3481          NaT
# 3482          NaT
# 3483          NaT
# 3484          NaT
# Name: Date Flown, Length: 3485, dtype: datetime64[ns]

# %%
# Check the structure of the dataset
print(df.head())
print(df.info())
# Out:
#                                              Reviews  Ratings  \
# 0  ✅ Trip Verified |  At 7.54 am on the day of tr...      2.0
# 1  ✅ Trip Verified |  Would happily fly them agai...     10.0
# 2  Not Verified |  Flew premium, only worth the e...      4.0
# 3  ✅ Trip Verified |  First our morning flight wa...      1.0
# 4  ✅ Trip Verified |  Although it was a bit uncom...      8.0
#
#        Aircraft Type       Traveller       Countries    Flight Ticket  \
# 0                NaN    Solo Leisure  United Kingdom    Economy Class
# 1  Boeing 777 / A320    Solo Leisure   United States    Economy Class
# 2                NaN  Couple Leisure  United Kingdom  Premium Economy
# 3            A321neo        Business          Canada   Business Class
# 4         Boeing 787    Solo Leisure  United Kingdom    Economy Class
#
#                              Route Date Flown  Seat Comfort /5  \
# 0            London to Los Angeles 2023-03-01              1.0
# 1  New York to Istanbul via London 2023-03-01              5.0
# 2     London Heathrow to Las Vegas 2023-03-01              3.0
# 3                  London to Cairo 2023-01-01              1.0
# 4                London Singapore  2023-02-01              3.0
#
#    Cabin Staff Services /5  Food and beverages /5  Ground service /5  \
# 0                      2.0                    1.0                3.0
# 1                      5.0                    5.0                5.0
# 2                      2.0                    1.0                2.0
# 3                      2.0                    1.0                3.0
# 4                      5.0                    5.0                5.0
#
#    Value for money /5 Recommended  verified  \
# 0                   1          no      True
# 1                   5         yes      True
# 2                   3          no     False
# 3                   1          no      True
# 4                   4         yes      True
#
#                                               corpus
# 0  day travel whilst driving london heathrow rece...
# 1  would happily fly personal emergency allowed r...
# 2  verified flew premium worth extra money bit ex...
# 3  first morning flight cancelled moved afternoon...
# 4  although bit uncomfortable flight economy flig...
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3485 entries, 0 to 3484
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Reviews                  3485 non-null   object
#  1   Ratings                  3480 non-null   float64
#  2   Aircraft Type            1824 non-null   object
#  3   Traveller                2715 non-null   object
#  4   Countries                3483 non-null   object
#  5   Flight Ticket            3483 non-null   object
#  6   Route                    2711 non-null   object
#  7   Date Flown               2707 non-null   datetime64[ns]
#  8   Seat Comfort /5          3385 non-null   float64
#  9   Cabin Staff Services /5  3377 non-null   float64
#  10  Food and beverages /5    3147 non-null   float64
#  11  Ground service /5        2647 non-null   float64
#  12  Value for money /5       3485 non-null   int64
#  13  Recommended              3485 non-null   object
#  14  verified                 3485 non-null   bool
#  15  corpus                   3485 non-null   object
# dtypes: bool(1), datetime64[ns](1), float64(5), int64(1), object(8)
# memory usage: 439.0+ KB
# None

# %%
# Explore the variables and their distributions
print(df.describe())

# Check for missing values
print(df.isnull().sum())
# Out:
#            Ratings  Seat Comfort /5  Cabin Staff Services /5  \
# count  3480.000000      3385.000000              3377.000000
# mean      4.843103         2.902511                 3.279538
# std       3.163383         1.361171                 1.487320
# min       1.000000         1.000000                 1.000000
# 25%       2.000000         2.000000                 2.000000
# 50%       4.000000         3.000000                 4.000000
# 75%       8.000000         4.000000                 5.000000
# max      10.000000         5.000000                 5.000000
#
#        Food and beverages /5  Ground service /5  Value for money /5
# count            3147.000000        2647.000000         3485.000000
# mean                2.736257           2.845485            2.738020
# std                 1.442597           1.446685            1.468167
# min                 0.000000           1.000000            0.000000
# 25%                 1.000000           1.000000            1.000000
# 50%                 3.000000           3.000000            3.000000
# 75%                 4.000000           4.000000            4.000000
# max                 5.000000           5.000000            5.000000
# Reviews                       0
# Ratings                       5
# Aircraft Type              1661
# Traveller                   770
# Countries                     2
# Flight Ticket                 2
# Route                       774
# Date Flown                  778
# Seat Comfort /5             100
# Cabin Staff Services /5     108
# Food and beverages /5       338
# Ground service /5           838
# Value for money /5            0
# Recommended                   0
# verified                      0
# corpus                        0
# dtype: int64

# %% [markdown]
# ### saving checkpoint

# %%
import os

cwd = os.getcwd()
df.to_csv(cwd+ "/BA_amended.csv")

# %%
df = pd.read_csv(cwd+"/BA_amended.csv", index_col=0)

# %%
# removing empty columns
cols_to_check = ['Reviews', 'Ratings', 'Aircraft Type', 'Countries',
                 'Flight Ticket', 'Route', 'Date Flown',
                'Seat Comfort /5', 'Cabin Staff Services /5',
                 'Food and beverages /5', 'Ground service /5',
                'Value for money /5', 'Recommended', 'verified',
                'corpus'] # replace with the names of the columns you want to check for missing values

# select only the rows where at least one value is missing in any of the columns
missing_rows = df[df[cols_to_check].isnull().any(axis=1)]

# display the number of rows with missing values
print(f"{len(missing_rows)} rows with missing values.")

# drop the rows with missing values and update the DataFrame in place
df.drop(missing_rows.index, inplace=True)

# display the number of remaining rows in the DataFrame
print(f"{len(df)} rows remaining after dropping missing values.")
# Out:
# 1780 rows with missing values.
# 1705 rows remaining after dropping missing values.

# %%
df.head(40)
# Out:
#                                               Reviews  Ratings  \
# 1   ✅ Trip Verified |  Would happily fly them agai...     10.0
# 3   ✅ Trip Verified |  First our morning flight wa...      1.0
# 4   ✅ Trip Verified |  Although it was a bit uncom...      8.0
# 5   ✅ Trip Verified |  Boarding was decently organ...      6.0
# 6   ✅ Trip Verified | Boarding on time and departu...      7.0
# 9   ✅ Trip Verified |  Very competent check in sta...      4.0
# 10  ✅ Trip Verified |  Check in was so slow, no se...      5.0
# 11  ✅ Trip Verified |  My review relates to the ap...      1.0
# 14  ✅ Trip Verified | BA 242 on the 6/2/23. Boardi...      9.0
# 15  ✅ Trip Verified |  Not only my first flight in...     10.0
# 17  ✅ Trip Verified | Organised boarding process. ...     10.0
# 19  ✅ Trip Verified | Check in agent at LHR was ve...      4.0
# 21  ✅ Trip Verified | Excellent service both on th...      9.0
# 22  ✅ Trip Verified |  Good lounge at Cape Town. O...      9.0
# 23  ✅ Trip Verified |  A really excellent journey....      9.0
# 27  ✅ Trip Verified |  A rather empty and quiet fl...      9.0
# 28  ✅ Trip Verified |  Easy check in and staff mem...      9.0
# 31  ✅ Trip Verified |  Flew ATL to LHR 8th Jan 202...      4.0
# 32  Not Verified |  Great thing about British Airw...      5.0
# 34  ✅ Trip Verified | Probably the worst business ...      1.0
# 36  ✅ Trip Verified |  BA shuttle service across t...      8.0
# 37  ✅ Trip Verified | I must admit like many other...      6.0
# 38  Not Verified |  When will BA update their Busi...      4.0
# 39  ✅ Trip Verified |  Paid £200 day before flight...      4.0
# 40  ✅ Trip Verified |  BA website did not work (we...      3.0
# 43  ✅ Trip Verified |  Old A320 with narrow pitch....      8.0
# 44  ✅ Trip Verified |  Another BA Shambles. Starte...      3.0
# 50  ✅ Trip Verified |  British Airways are not the...      6.0
# 51  ✅ Trip Verified |  Stupidly tried BA again aft...      1.0
# 52  Not Verified |  Seat horribly narrow; 3-4-3 on...      8.0
# 53  ✅ Trip Verified |  Glasgow to London delayed b...      3.0
# 54  ✅ Trip Verified |  When I tried to check in on...      6.0
# 55  ✅ Trip Verified |  I flew from Prague to LHR. ...      3.0
# 58  ✅ Trip Verified |  I was flying to Warsaw for ...      1.0
# 59  ✅ Trip Verified |  Booked a BA holiday to Marr...      9.0
# 60  ✅ Trip Verified | Extremely sub-par service. H...      2.0
# 61  ✅ Trip Verified |  I virtually gave up on Brit...      7.0
# 62  ✅ Trip Verified |  I was pleasantly surprised ...      7.0
# 66  ✅ Trip Verified |  Flying LHR T5 to CPT Novemb...      2.0
# 68  ✅ Trip Verified |  Check in was a shambles at ...      5.0
#
#         Aircraft Type       Traveller             Countries    Flight Ticket  \
# 1   Boeing 777 / A320    Solo Leisure         United States    Economy Class
# 3             A321neo        Business                Canada   Business Class
# 4          Boeing 787    Solo Leisure        United Kingdom    Economy Class
# 5                A380        Business               Belgium   Business Class
# 6                A320        Business               Belgium   Business Class
# 9                A320  Couple Leisure  United Arab Emirates    Economy Class
# 10               A320  Family Leisure        United Kingdom    Economy Class
# 11               A320    Solo Leisure        United Kingdom    Economy Class
# 14       Boeing 787-9  Couple Leisure        United Kingdom   Business Class
# 15               A320    Solo Leisure                 Spain    Economy Class
# 17               A320        Business        United Kingdom    Economy Class
# 19     Boeing 777-300    Solo Leisure        United Kingdom  Premium Economy
# 21               A380    Solo Leisure        United Kingdom      First Class
# 22     Boeing 777-200  Couple Leisure        United Kingdom   Business Class
# 23   Boeing 777-300ER  Couple Leisure        United Kingdom   Business Class
# 27       Boeing 787-8  Family Leisure        United Kingdom    Economy Class
# 28     Boeing 777-200  Couple Leisure        United Kingdom   Business Class
# 31     Boeing 777-200  Family Leisure        United Kingdom    Economy Class
# 32               A380  Family Leisure        United Kingdom    Economy Class
# 34         A320, A380  Family Leisure         United States   Business Class
# 36               A321        Business        United Kingdom    Economy Class
# 37               A380        Business        United Kingdom    Economy Class
# 38         Boeing 777  Couple Leisure        United Kingdom   Business Class
# 39         Boeing 777    Solo Leisure        United Kingdom  Premium Economy
# 40               A350    Solo Leisure        United Kingdom   Business Class
# 43               A320  Couple Leisure                France    Economy Class
# 44     Boeing 777-300  Couple Leisure        United Kingdom      First Class
# 50               A321        Business        United Kingdom   Business Class
# 51         Boeing 777  Couple Leisure        United Kingdom   Business Class
# 52     Boeing 777-200    Solo Leisure           New Zealand    Economy Class
# 53               A320        Business        United Kingdom   Business Class
# 54         Boeing 777  Couple Leisure        United Kingdom  Premium Economy
# 55               A320    Solo Leisure        Czech Republic   Business Class
# 58       Boeing 787-9        Business         United States    Economy Class
# 59               A320    Solo Leisure        United Kingdom   Business Class
# 60               A380    Solo Leisure         United States    Economy Class
# 61               A320    Solo Leisure        United Kingdom   Business Class
# 62  Boeing 787 / A320    Solo Leisure                Canada    Economy Class
# 66         Boeing 777    Solo Leisure        United Kingdom   Business Class
# 68       Boeing 787-8    Solo Leisure              Malaysia    Economy Class
#
#                                         Route     Date Flown  Seat Comfort /5  \
# 1             New York to Istanbul via London     March 2023              5.0
# 3                             London to Cairo   January 2023              1.0
# 4                           London Singapore   February 2023              3.0
# 5                             London to Dubai  February 2023              2.0
# 6                          Brussels to London  February 2023              2.0
# 9                            Faro to Gatwick   February 2023              2.0
# 10                             Oslo to London  February 2023              3.0
# 11                           London to Madrid  February 2023              2.0
# 14                      Mexico City to London  February 2023              5.0
# 15                           Palma to Gatwick   January 2023              5.0
# 17                 London Heathrow to Glasgow   January 2023              5.0
# 19                        London to Vancouver   January 2023              4.0
# 21                   Heathrow to Johannesburg   January 2023              4.0
# 22                        Cape Town to London   January 2023              4.0
# 23                             London to Male   January 2023              5.0
# 27                         London to Tel Aviv  December 2022              4.0
# 28               London Heathrow to Cape Town   January 2023              3.0
# 31                          Atlanta to London   January 2023              1.0
# 32                          London to Chicago  December 2022              3.0
# 34  Vienna to Los Angeles via London Heathrow   January 2023              1.0
# 36                          London to Belfast   January 2023              4.0
# 37                             Doha to London  December 2022              5.0
# 38                         London to Barbados  December 2022              3.0
# 39                London Gatwick to Cape Town  December 2022              3.0
# 40                        Cape Town to London  December 2022              4.0
# 43                        Marseille to London  December 2022              3.0
# 44                             London to Male  December 2022              2.0
# 50                             London to Rome  December 2022              4.0
# 51                Barbados to London Heathrow  December 2022              1.0
# 52                           Doha to  Gatwick  November 2022              2.0
# 53                          Glasgow to London  December 2022              5.0
# 54                           London to Boston  December 2022              3.0
# 55                           London to Prague  November 2022              2.0
# 58                           Denver to London  December 2022              1.0
# 59                        London to Marrakech      June 2022              3.0
# 60                    San Francisco to London  November 2022              2.0
# 61                           London to Lisbon  November 2022              3.0
# 62  Montreal to Edinburgh via London Heathrow   January 2022              4.0
# 66                        London to Cape Town  November 2022              4.0
# 68               Baltimore to London Heathrow  November 2022              1.0
#
#     Cabin Staff Services /5  Food and beverages /5  Ground service /5  \
# 1                       5.0                    5.0                5.0
# 3                       2.0                    1.0                3.0
# 4                       5.0                    5.0                5.0
# 5                       3.0                    2.0                4.0
# 6                       4.0                    4.0                4.0
# 9                       2.0                    1.0                5.0
# 10                      3.0                    1.0                2.0
# 11                      1.0                    1.0                1.0
# 14                      5.0                    4.0                5.0
# 15                      5.0                    5.0                5.0
# 17                      5.0                    4.0                5.0
# 19                      4.0                    1.0                4.0
# 21                      5.0                    4.0                5.0
# 22                      5.0                    5.0                4.0
# 23                      5.0                    5.0                5.0
# 27                      5.0                    4.0                4.0
# 28                      5.0                    5.0                4.0
# 31                      1.0                    1.0                1.0
# 32                      2.0                    3.0                3.0
# 34                      2.0                    1.0                1.0
# 36                      5.0                    3.0                5.0
# 37                      3.0                    1.0                5.0
# 38                      4.0                    4.0                4.0
# 39                      4.0                    4.0                2.0
# 40                      3.0                    2.0                1.0
# 43                      3.0                    2.0                4.0
# 44                      2.0                    1.0                3.0
# 50                      4.0                    5.0                1.0
# 51                      1.0                    1.0                1.0
# 52                      5.0                    4.0                3.0
# 53                      5.0                    3.0                5.0
# 54                      4.0                    3.0                3.0
# 55                      1.0                    1.0                2.0
# 58                      1.0                    1.0                1.0
# 59                      5.0                    5.0                4.0
# 60                      1.0                    2.0                3.0
# 61                      4.0                    4.0                3.0
# 62                      4.0                    4.0                4.0
# 66                      2.0                    1.0                1.0
# 68                      3.0                    3.0                2.0
#
#     Value for money /5 Recommended  verified  \
# 1                    5         yes      True
# 3                    1          no      True
# 4                    4         yes      True
# 5                    3         yes      True
# 6                    4         yes      True
# 9                    2          no      True
# 10                   3          no      True
# 11                   2          no      True
# 14                   5         yes      True
# 15                   5         yes      True
# 17                   5         yes      True
# 19                   1          no      True
# 21                   4         yes      True
# 22                   4         yes      True
# 23                   4         yes      True
# 27                   5         yes      True
# 28                   4         yes      True
# 31                   2          no      True
# 32                   2          no     False
# 34                   1          no      True
# 36                   4         yes      True
# 37                   4          no      True
# 38                   3          no     False
# 39                   3          no      True
# 40                   2          no      True
# 43                   5         yes      True
# 44                   1          no      True
# 50                   4         yes      True
# 51                   1          no      True
# 52                   5         yes     False
# 53                   3          no      True
# 54                   3         yes      True
# 55                   1          no      True
# 58                   1          no      True
# 59                   3         yes      True
# 60                   2          no      True
# 61                   3         yes      True
# 62                   4         yes      True
# 66                   1          no      True
# 68                   3         yes      True
#
#                                                corpus
# 1   would happily fly personal emergency allowed r...
# 3   first morning flight cancelled moved afternoon...
# 4   although bit uncomfortable flight economy flig...
# 5   boarding decently organised still rather stran...
# 6   boarding time departure time flight london hea...
# 9   competent check staff saw problem left arm ins...
# 10  check slow self check bag drop boarding ok fli...
# 11  review relates appalling experience british ai...
# 14  ba boarding delayed due late arrival incoming ...
# 15  first flight year also first time back england...
# 17  organised boarding process really friendly cre...
# 19  check agent lhr helpful friendly flight crew s...
# 21  excellent service ground board first class pro...
# 22  good lounge cape town time departure drink hig...
# 23  really excellent journey lounge overcrowded la...
# 27  rather empty quiet flight tel aviv friendly ca...
# 28  easy check staff member polite helpful made sp...
# 31  flew atl lhr th jan unlucky enough board year ...
# 32  verified great thing british airway economy se...
# 34  probably worst business class experience ever ...
# 36  ba shuttle service across uk still surprisingl...
# 37  must admit like many others tend avoid ba long...
# 38  verified ba update business class cabin across...
# 39  paid day flight upgrade economy premium econom...
# 40  ba website work weirdly deleted flight upcomin...
# 43  old narrow pitch flight perfectly time constan...
# 44  another ba shamble started well excellent chec...
# 50  british airway flag carrier used check staff c...
# 51  stupidly tried ba five year gap paid wife go b...
# 52  verified seat horribly narrow thankfully fligh...
# 53  glasgow london delayed hour wife accept ba fli...
# 54  tried check online offered upgrade premium eco...
# 55  flew prague lhr excellent service attentive st...
# 58  flying warsaw one day meeting would flying bac...
# 59  booked ba holiday marrakech posting negative r...
# 60  extremely sub par service highlight online mea...
# 61  virtually gave british airway three year ago w...
# 62  pleasantly surprised airline could maintain st...
# 66  flying lhr cpt november ba app website working...
# 68  check shamble bwi counter open full flight bag...

# %%
df.reset_index(drop=True)
# Out:
#                                                 Reviews  Ratings  \
# 0     ✅ Trip Verified |  Would happily fly them agai...     10.0
# 1     ✅ Trip Verified |  First our morning flight wa...      1.0
# 2     ✅ Trip Verified |  Although it was a bit uncom...      8.0
# 3     ✅ Trip Verified |  Boarding was decently organ...      6.0
# 4     ✅ Trip Verified | Boarding on time and departu...      7.0
# ...                                                 ...      ...
# 1700  BA0567 15/6/15. There was a delay, which I und...      8.0
# 1701  I flew from Seoul to London, business class an...      6.0
# 1702  Ended up on a 25-year-old 747, the second-olde...      6.0
# 1703  We were boarded quickly but suffered a weather...      9.0
# 1704  Terrible. Flight time is well over 2 hours. Se...      1.0
#
#           Aircraft Type       Traveller       Countries   Flight Ticket  \
# 0     Boeing 777 / A320    Solo Leisure   United States   Economy Class
# 1               A321neo        Business          Canada  Business Class
# 2            Boeing 787    Solo Leisure  United Kingdom   Economy Class
# 3                  A380        Business         Belgium  Business Class
# 4                  A320        Business         Belgium  Business Class
# ...                 ...             ...             ...             ...
# 1700               A320    Solo Leisure  United Kingdom   Economy Class
# 1701         boeing 787    Solo Leisure  United Kingdom  Business Class
# 1702           B747-400    Solo Leisure          Canada   Economy Class
# 1703               A320  Couple Leisure  United Kingdom   Economy Class
# 1704               A321        Business  United Kingdom  Business Class
#
#                                 Route     Date Flown  Seat Comfort /5  \
# 0     New York to Istanbul via London     March 2023              5.0
# 1                     London to Cairo   January 2023              1.0
# 2                   London Singapore   February 2023              3.0
# 3                     London to Dubai  February 2023              2.0
# 4                  Brussels to London  February 2023              2.0
# ...                               ...            ...              ...
# 1700            LHR to Milan Malpensa      June 2015              4.0
# 1701                  Seoul to London      June 2015              4.0
# 1702                       LHR to YYZ       May 2015              3.0
# 1703                       LGW to VCE      June 2015              3.0
# 1704                       LHR to SOF       May 2015              1.0
#
#       Cabin Staff Services /5  Food and beverages /5  Ground service /5  \
# 0                         5.0                    5.0                5.0
# 1                         2.0                    1.0                3.0
# 2                         5.0                    5.0                5.0
# 3                         3.0                    2.0                4.0
# 4                         4.0                    4.0                4.0
# ...                       ...                    ...                ...
# 1700                      5.0                    4.0                4.0
# 1701                      3.0                    3.0                3.0
# 1702                      4.0                    4.0                4.0
# 1703                      5.0                    3.0                4.0
# 1704                      3.0                    2.0                3.0
#
#       Value for money /5 Recommended  verified  \
# 0                      5         yes      True
# 1                      1          no      True
# 2                      4         yes      True
# 3                      3         yes      True
# 4                      4         yes      True
# ...                  ...         ...       ...
# 1700                   4         yes     False
# 1701                   3         yes     False
# 1702                   4         yes     False
# 1703                   4         yes     False
# 1704                   1          no     False
#
#                                                  corpus
# 0     would happily fly personal emergency allowed r...
# 1     first morning flight cancelled moved afternoon...
# 2     although bit uncomfortable flight economy flig...
# 3     boarding decently organised still rather stran...
# 4     boarding time departure time flight london hea...
# ...                                                 ...
# 1700  ba delay understand accept crew helpful went w...
# 1701  flew seoul london business class surprised muc...
# 1702  ended year old second oldest ba fleet boy show...
# 1703  boarded quickly suffered weather delay hour lo...
# 1704  ble flight time well hour seating like ryanair...
#
# [1705 rows x 16 columns]

# %%
# export the cleaned data
df.to_csv(cwd + "/cleaned-BA-reviews.csv")
